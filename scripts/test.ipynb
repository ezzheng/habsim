# %%
import numpy as np

data = np.load('/Applications/Emmanuel Zheng/habsim/data/worldelev.npy', mmap_mode='r')
print("Shape:", data.shape)
print("Top-left corner (northwest):", data[0, 0])
print("Bottom-right corner (southeast):", data[-1, -1])
# Out:
# Shape: (10440, 21600)
# Top-left corner (northwest): 0
# Bottom-right corner (southeast): 2801
